# %%
#variables

x=10
y="a"
z=True
print(x,y,z)
# Out:
# 10 a True

# %%
#input & output

name=input("Enter your name: ")
age=int(input("Enter your age: "))
if age<18:
    print("Not eligible")
else:
    print("Eligible")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 #input & output
#       2
# ----> 3 name=input("Enter your name: ")
#       4 age=int(input("Enter your age: "))
#       5 if age<18:
#       6     print("Not eligible")
#
# File c:\Users\vedik\OneDrive\Desktop\DSA\source-code\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\vedik\OneDrive\Desktop\DSA\source-code\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#type conversion

print(int("101"))
print(float("23"))
print(int(23.767))
print(bool(1))
print(str(100))
list("abc")
# Out:
# 101
# 23.0
# 23
# True
# 100
# ['a', 'b', 'c']

# %%
#operators

a=10
b=5
print(a+b, a//b, a**b)
print(a==b, a!=b, a>b, a<b)
a+=1
b-=1
print(a,b)
# Out:
# 15 2 100000
# False True True False
# 11 4

# %%
#loops

for i in range(0,5):
    print(i)
a=3
print("\n")
while(a>0):
    print(a)
    a -=1
# Out:
# 0
# 1
# 2
# 3
# 4
#
#
# 3
# 2
# 1

# %%
#functions

def add(a,b):
    return a+b
add(2,5)
# Out:
# 7

# %%
#lists

#creating
arr=[3,13,1,5]
#accessing
arr[2]
arr[-1]
#slicing
arr[1:3]
arr[::-1]
#methods
arr.append(10)
arr.remove(1)
arr.pop()
arr.reverse()
arr.count(2)
for item in arr:
    print(item)
# Out:
# [5, 1, 13, 3]

# %%
#Enumeration
fruits=["banana","apple","mango","grapes"]
for index, fruit in enumerate(fruits):
    print(f"Index {index}: {fruit}")
# Out:
# Index 0: banana
# Index 1: apple
# Index 2: mango
# Index 3: grapes

# %%
#strings

s="abc,,"
s[0]
#slicing string
s[0:3]
#reverse
s[::-1]
#methods
s.lower()
s.upper()
s.strip(",")
b="welcome to python"
b.split(" ")
# Out:
# ['welcome', 'to', 'python']

# %%
#tupples
a=(1,2,3)
print(a)
# Out:
# (1, 2, 3)

# %%
#dictionary
person={
    "name":"vedik",
    "age":"19",
    "city":"Hyderabad"
}
print(person["name"])
print(person.get("age"))

person["Roll number"]="24R21A6771"
for key, value in person.items():
    print(f"{key} : {value}")
# Out:
# vedik
# 19
# name : vedik
# age : 19
# city : Hyderabad
# Roll number : 24R21A6771
